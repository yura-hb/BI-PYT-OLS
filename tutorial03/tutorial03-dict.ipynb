# %% [markdown]
# # Slovníky (dict)

# %% [markdown]
# ### 1. Zanalyzujte vstupní textový soubor následujícím způsobem: Vytvořte slovník, jehož klíči budou jednotlivá písmena a hodnotami počet jejich výskytů v textu. Uvedený slovník vypište pomocí pprint.pprint().

# %%
from pprint import pprint
# TODO: Implement your solution.
dic = {}
with open("leacock-abc.txt") as f:
    for x in f:
        for g in x.lower():
            if not g.isalpha():
                continue
            if dic.get(g) is None:
                dic[g] = 1
            else:
                dic[g] += 1
            
pprint(dic)
# Out:
# {'a': 649,
#  'b': 137,
#  'c': 217,
#  'd': 331,
#  'e': 831,
#  'f': 183,
#  'g': 170,
#  'h': 432,
#  'i': 528,
#  'j': 9,
#  'k': 68,
#  'l': 294,
#  'm': 203,
#  'n': 540,
#  'o': 536,
#  'p': 107,
#  'q': 7,
#  'r': 397,
#  's': 439,
#  't': 645,
#  'u': 174,
#  'v': 53,
#  'w': 166,
#  'x': 8,
#  'y': 138,
#  'z': 4}

# %% [markdown]
# ### 2.  Rozšiřte předchozí program tak, že hodnotou bude objekt o dvou prvcích – prvním bude počet výskytů daného písmene v textu, druhým jeho relativní četnost v % (vzhledem k počtu všech písmen v textu).

# %%
# TODO: Implement your solution.

count = sum(dic.values())
f = lambda x, y: (x, x / y * 100)

dic = { key : f(value, count) for key, value in dic.items() }
pprint(dic)
# Out:
# {'a': (76, 4.2720629567172566),
#  "a's": (1, 0.056211354693648116),
#  'abjured': (1, 0.056211354693648116),
#  'about': (3, 0.16863406408094433),
#  'above': (1, 0.056211354693648116),
#  'absence': (1, 0.056211354693648116),
#  'accidentally': (1, 0.056211354693648116),
#  'accustomed': (1, 0.056211354693648116),
#  'acquaintances': (1, 0.056211354693648116),
#  'actual': (1, 0.056211354693648116),
#  'admiration': (1, 0.056211354693648116),
#  'adventure': (1, 0.056211354693648116),
#  'affected': (1, 0.056211354693648116),
#  'afraid': (1, 0.056211354693648116),
#  'after': (7, 0.39347948285553686),
#  'again': (2, 0.11242270938729623),
#  'again."--the': (1, 0.056211354693648116),
#  'aged': (1, 0.056211354693648116),
#  'aggravated': (1, 0.056211354693648116),
#  'aimlessly': (1, 0.056211354693648116),
#  'alarmed': (1, 0.056211354693648116),
#  'algebra': (1, 0.056211354693648116),
#  'algebraica': (1, 0.056211354693648116),
#  'all': (5, 0.2810567734682406),
#  'alpha': (1, 0.056211354693648116),
#  'also': (1, 0.056211354693648116),
#  'always': (3, 0.16863406408094433),
#  'ambitions': (1, 0.056211354693648116),
#  'an': (5, 0.2810567734682406),
#  'and': (80, 4.4969083754918495),
#  'answer': (1, 0.056211354693648116),
#  'answered': (2, 0.11242270938729623),
#  'any': (2, 0.11242270938729623),
#  'appear': (1, 0.056211354693648116),
#  'aquatic': (1, 0.056211354693648116),
#  'arduous': (1, 0.056211354693648116),
#  'are': (9, 0.5059021922428331),
#  'arithmetic': (2, 0.11242270938729623),
#  'arithmetics': (1, 0.056211354693648116),
#  'arms': (1, 0.056211354693648116),
#  'arrived': (1, 0.056211354693648116),
#  'art': (1, 0.056211354693648116),
#  'as': (26, 1.4614952220348512),
#  'asked': (1, 0.056211354693648116),
#  'aspirations': (1, 0.056211354693648116),
#  'associates': (1, 0.056211354693648116),
#  'asylum': (1, 0.056211354693648116),
#  'at': (11, 0.6183249016301293),
#  'aught': (1, 0.056211354693648116),
#  'away': (1, 0.056211354693648116),
#  'b': (28, 1.5739179314221474),
#  'badly': (1, 0.056211354693648116),
#  'bank': (2, 0.11242270938729623),
#  'be': (2, 0.11242270938729623),
#  'beat': (1, 0.056211354693648116),
#  'became': (5, 0.2810567734682406),
#  'become': (2, 0.11242270938729623),
#  'bed': (3, 0.16863406408094433),
#  'been': (7, 0.39347948285553686),
#  'beginner': (1, 0.056211354693648116),
#  'being': (1, 0.056211354693648116),
#  'bends': (1, 0.056211354693648116),
#  'best': (1, 0.056211354693648116),
#  'bet': (2, 0.11242270938729623),
#  'beta': (1, 0.056211354693648116),
#  'betraying': (1, 0.056211354693648116),
#  'bets': (2, 0.11242270938729623),
#  'bets.--b': (1, 0.056211354693648116),
#  'bicycle': (2, 0.11242270938729623),
#  'bit': (2, 0.11242270938729623),
#  'blood': (1, 0.056211354693648116),
#  'blunder': (1, 0.056211354693648116),
#  'blustering': (2, 0.11242270938729623),
#  'book': (1, 0.056211354693648116),
#  'bore': (1, 0.056211354693648116),
#  'borrows': (1, 0.056211354693648116),
#  'both': (2, 0.11242270938729623),
#  'bottom': (1, 0.056211354693648116),
#  'bowed': (1, 0.056211354693648116),
#  'box': (1, 0.056211354693648116),
#  'bracket': (2, 0.11242270938729623),
#  'brackets': (1, 0.056211354693648116),
#  'breathing': (1, 0.056211354693648116),
#  'broken': (2, 0.11242270938729623),
#  'brotherly': (1, 0.056211354693648116),
#  'bullied': (1, 0.056211354693648116),
#  'burst': (1, 0.056211354693648116),
#  'busy': (1, 0.056211354693648116),
#  'but': (9, 0.5059021922428331),
#  'by': (5, 0.2810567734682406),
#  'c': (32, 1.7987633501967397),
#  "c's": (3, 0.16863406408094433),
#  'called': (4, 0.22484541877459246),
#  'came': (3, 0.16863406408094433),
#  'can': (11, 0.6183249016301293),
#  'capital': (1, 0.056211354693648116),
#  'case': (1, 0.056211354693648116),
#  'cemetery': (2, 0.11242270938729623),
#  'certain': (5, 0.2810567734682406),
#  'challenges': (1, 0.056211354693648116),
#  'chanced': (1, 0.056211354693648116),
#  'changed': (1, 0.056211354693648116),
#  'changing': (1, 0.056211354693648116),
#  'chapters': (1, 0.056211354693648116),
#  'characters': (1, 0.056211354693648116),
#  'charm': (1, 0.056211354693648116),
#  'christian': (1, 0.056211354693648116),
#  'cistern': (3, 0.16863406408094433),
#  'cisterns': (2, 0.11242270938729623),
#  'clear': (1, 0.056211354693648116),
#  'clearly': (1, 0.056211354693648116),
#  'clothes': (1, 0.056211354693648116),
#  'come': (2, 0.11242270938729623),
#  'commercial': (1, 0.056211354693648116),
#  'common': (1, 0.056211354693648116),
#  'competes': (1, 0.056211354693648116),
#  'concealed': (1, 0.056211354693648116),
#  'condition': (1, 0.056211354693648116),
#  'confronted': (1, 0.056211354693648116),
#  'consented': (1, 0.056211354693648116),
#  'constant': (1, 0.056211354693648116),
#  'constantly': (1, 0.056211354693648116),
#  'containing': (1, 0.056211354693648116),
#  'contented': (1, 0.056211354693648116),
#  'cord': (2, 0.11242270938729623),
#  'cottage': (1, 0.056211354693648116),
#  'coughing': (1, 0.056211354693648116),
#  'could': (3, 0.16863406408094433),
#  'countless': (1, 0.056211354693648116),
#  'course': (2, 0.11242270938729623),
#  'creatures': (1, 0.056211354693648116),
#  'current': (1, 0.056211354693648116),
#  'd': (2, 0.11242270938729623),
#  'dallying': (1, 0.056211354693648116),
#  'day': (2, 0.11242270938729623),
#  'dead': (1, 0.056211354693648116),
#  'death': (2, 0.11242270938729623),
#  'decimal': (1, 0.056211354693648116),
#  'deepened': (1, 0.056211354693648116),
#  'deference': (1, 0.056211354693648116),
#  'define': (1, 0.056211354693648116),
#  'delta': (1, 0.056211354693648116),
#  'denominator': (1, 0.056211354693648116),
#  'deranged': (1, 0.056211354693648116),
#  'devoted': (1, 0.056211354693648116),
#  'did': (2, 0.11242270938729623),
#  'differed': (1, 0.056211354693648116),
#  'difficulty': (1, 0.056211354693648116),
#  'dig': (5, 0.2810567734682406),
#  'digging': (2, 0.11242270938729623),
#  'digs': (1, 0.056211354693648116),
#  'dirty': (1, 0.056211354693648116),
#  'disease': (1, 0.056211354693648116),
#  'distance': (1, 0.056211354693648116),
#  'ditch': (1, 0.056211354693648116),
#  'ditch-digging': (1, 0.056211354693648116),
#  'ditches': (1, 0.056211354693648116),
#  'division': (1, 0.056211354693648116),
#  'do': (6, 0.33726812816188867),
#  'doctor': (3, 0.16863406408094433),
#  'doing': (1, 0.056211354693648116),
#  "don't": (1, 0.056211354693648116),
#  'done': (1, 0.056211354693648116),
#  'down': (1, 0.056211354693648116),
#  'downstairs': (1, 0.056211354693648116),
#  'draught': (2, 0.11242270938729623),
#  'drink': (1, 0.056211354693648116),
#  'driven': (1, 0.056211354693648116),
#  'driving': (2, 0.11242270938729623),
#  'dug': (1, 0.056211354693648116),
#  'dying': (1, 0.056211354693648116),
#  'early': (1, 0.056211354693648116),
#  'easy-going': (1, 0.056211354693648116),
#  'eating': (1, 0.056211354693648116),
#  'element': (2, 0.11242270938729623),
#  'em': (2, 0.11242270938729623),
#  'employed': (1, 0.056211354693648116),
#  'employing': (1, 0.056211354693648116),
#  'empty': (1, 0.056211354693648116),
#  'end': (4, 0.22484541877459246),
#  'endurance': (1, 0.056211354693648116),
#  'energetic': (1, 0.056211354693648116),
#  'engage': (1, 0.056211354693648116),
#  'engaged': (1, 0.056211354693648116),
#  'entered': (1, 0.056211354693648116),
#  'etc': (2, 0.11242270938729623),
#  'euclid': (1, 0.056211354693648116),
#  'euclid.--it': (1, 0.056211354693648116),
#  'even': (2, 0.11242270938729623),
#  'evening': (2, 0.11242270938729623),
#  'ever': (3, 0.16863406408094433),
#  'everything': (1, 0.056211354693648116),
#  'except': (1, 0.056211354693648116),
#  'expanse': (1, 0.056211354693648116),
#  'expired': (1, 0.056211354693648116),
#  'face': (1, 0.056211354693648116),
#  'fact': (1, 0.056211354693648116),
#  'fagged': (1, 0.056211354693648116),
#  'family': (2, 0.11242270938729623),
#  'far': (1, 0.056211354693648116),
#  'fashion': (1, 0.056211354693648116),
#  'fast': (6, 0.33726812816188867),
#  'faster': (1, 0.056211354693648116),
#  'fatal': (1, 0.056211354693648116),
#  'feebly': (1, 0.056211354693648116),
#  'feel': (1, 0.056211354693648116),
#  'fellow': (3, 0.16863406408094433),
#  'fellows': (2, 0.11242270938729623),
#  'fetch': (3, 0.16863406408094433),
#  'figures': (1, 0.056211354693648116),
#  'filling': (1, 0.056211354693648116),
#  'finally': (1, 0.056211354693648116),
#  'find': (5, 0.2810567734682406),
#  'finds': (1, 0.056211354693648116),
#  'fine': (1, 0.056211354693648116),
#  'firmly': (1, 0.056211354693648116),
#  'first': (4, 0.22484541877459246),
#  'fit': (1, 0.056211354693648116),
#  'fix': (1, 0.056211354693648116),
#  'flared': (1, 0.056211354693648116),
#  'flesh': (1, 0.056211354693648116),
#  'flight': (1, 0.056211354693648116),
#  'flood': (1, 0.056211354693648116),
#  'followed': (1, 0.056211354693648116),
#  'foot': (1, 0.056211354693648116),
#  'for': (9, 0.5059021922428331),
#  'foreigners': (1, 0.056211354693648116),
#  'form': (1, 0.056211354693648116),
#  'former': (1, 0.056211354693648116),
#  'forth': (1, 0.056211354693648116),
#  'fortnight': (1, 0.056211354693648116),
#  'forty-eight': (1, 0.056211354693648116),
#  'found': (2, 0.11242270938729623),
#  'four': (7, 0.39347948285553686),
#  'fractions': (1, 0.056211354693648116),
#  'frail': (1, 0.056211354693648116),
#  'frenzy': (1, 0.056211354693648116),
#  'friend': (1, 0.056211354693648116),
#  'from': (6, 0.33726812816188867),
#  'front': (1, 0.056211354693648116),
#  'full': (2, 0.11242270938729623),
#  'full-blooded': (1, 0.056211354693648116),
#  'funeral': (1, 0.056211354693648116),
#  'gamma': (1, 0.056211354693648116),
#  'garden': (3, 0.16863406408094433),
#  'garrulous': (1, 0.056211354693648116),
#  'gave': (1, 0.056211354693648116),
#  'generally': (1, 0.056211354693648116),
#  'generously': (1, 0.056211354693648116),
#  'gentle': (1, 0.056211354693648116),
#  'get': (2, 0.11242270938729623),
#  'getting': (1, 0.056211354693648116),
#  'give': (1, 0.056211354693648116),
#  'go': (1, 0.056211354693648116),
#  'going': (4, 0.22484541877459246),
#  'good': (2, 0.11242270938729623),
#  'grave': (1, 0.056211354693648116),
#  'great': (1, 0.056211354693648116),
#  'grew': (1, 0.056211354693648116),
#  'grief': (1, 0.056211354693648116),
#  'grow': (1, 0.056211354693648116),
#  'growl': (1, 0.056211354693648116),
#  'had': (8, 0.44969083754918493),
#  'half': (1, 0.056211354693648116),
#  'hamlin': (2, 0.11242270938729623),
#  'hand': (1, 0.056211354693648116),
#  'handicap': (1, 0.056211354693648116),
#  'hardly': (1, 0.056211354693648116),
#  'has': (9, 0.5059021922428331),
#  'have': (2, 0.11242270938729623),
#  'having': (2, 0.11242270938729623),
#  'he': (25, 1.405283867341203),
#  "he's": (1, 0.056211354693648116),
#  'head': (2, 0.11242270938729623),
#  'health': (1, 0.056211354693648116),
#  'heard': (4, 0.22484541877459246),
#  'hearse': (1, 0.056211354693648116),
#  'hearses': (1, 0.056211354693648116),
#  'heave': (1, 0.056211354693648116),
#  'heavenward': (1, 0.056211354693648116),
#  'help': (1, 0.056211354693648116),
#  'helpless': (1, 0.056211354693648116),
#  'henry': (1, 0.056211354693648116),
#  'here': (3, 0.16863406408094433),
#  'him': (8, 0.44969083754918493),
#  'himself': (2, 0.11242270938729623),
#  'his': (22, 1.2366498032602586),
#  'historical': (1, 0.056211354693648116),
#  'history': (2, 0.11242270938729623),
#  'hoeing': (1, 0.056211354693648116),
#  'holes': (1, 0.056211354693648116),
#  'home': (2, 0.11242270938729623),
#  'horseback': (1, 0.056211354693648116),
#  'hot': (1, 0.056211354693648116),
#  'hot-headed': (1, 0.056211354693648116),
#  'hour': (4, 0.22484541877459246),
#  'hours': (2, 0.11242270938729623),
#  'how': (4, 0.22484541877459246),
#  'however': (1, 0.056211354693648116),
#  'human': (1, 0.056211354693648116),
#  'hundred': (1, 0.056211354693648116),
#  'i': (28, 1.5739179314221474),
#  "i'll": (2, 0.11242270938729623),
#  "i'm": (4, 0.22484541877459246),
#  'identity': (1, 0.056211354693648116),
#  'if': (3, 0.16863406408094433),
#  'ill': (2, 0.11242270938729623),
#  'ill-fated': (1, 0.056211354693648116),
#  'in': (50, 2.810567734682406),
#  'incarcerated': (1, 0.056211354693648116),
#  'indifferent': (1, 0.056211354693648116),
#  'industry': (1, 0.056211354693648116),
#  'inquiry': (1, 0.056211354693648116),
#  'intellect': (1, 0.056211354693648116),
#  'interest': (2, 0.11242270938729623),
#  'into': (3, 0.16863406408094433),
#  'is': (14, 0.7869589657110737),
#  "isn't": (1, 0.056211354693648116),
#  'it': (17, 0.9555930297920181),
#  'its': (1, 0.056211354693648116),
#  'job': (2, 0.11242270938729623),
#  'jobs': (1, 0.056211354693648116),
#  'john': (1, 0.056211354693648116),
#  'joyless': (1, 0.056211354693648116),
#  'just': (2, 0.11242270938729623),
#  'keep': (1, 0.056211354693648116),
#  'kill': (1, 0.056211354693648116),
#  'kind-heartedness-like': (1, 0.056211354693648116),
#  'know': (3, 0.16863406408094433),
#  'knowed': (1, 0.056211354693648116),
#  'known': (2, 0.11242270938729623),
#  'labour': (1, 0.056211354693648116),
#  'laboured': (1, 0.056211354693648116),
#  'labouring': (1, 0.056211354693648116),
#  'lacking': (1, 0.056211354693648116),
#  'lad': (1, 0.056211354693648116),
#  'languidly': (1, 0.056211354693648116),
#  'last': (2, 0.11242270938729623),
#  'lays': (1, 0.056211354693648116),
#  'leak': (2, 0.11242270938729623),
#  'leaks': (1, 0.056211354693648116),
#  'learned': (1, 0.056211354693648116),
#  'left': (2, 0.11242270938729623),
#  'leisure': (1, 0.056211354693648116),
#  'let': (1, 0.056211354693648116),
#  'life': (3, 0.16863406408094433),
#  'like': (1, 0.056211354693648116),
#  'line': (1, 0.056211354693648116),
#  'little': (7, 0.39347948285553686),
#  'live': (1, 0.056211354693648116),
#  'living': (1, 0.056211354693648116),
#  'locomotive': (1, 0.056211354693648116),
#  'locomotives': (1, 0.056211354693648116),
#  'logarithm': (1, 0.056211354693648116),
#  'long': (3, 0.16863406408094433),
#  'longer': (1, 0.056211354693648116),
#  'look': (1, 0.056211354693648116),
#  'looked': (1, 0.056211354693648116),
#  'lost': (3, 0.16863406408094433),
#  'lowered': (1, 0.056211354693648116),
#  'lowest': (1, 0.056211354693648116),
#  'lying': (1, 0.056211354693648116),
#  'm': (1, 0.056211354693648116),
#  'made': (1, 0.056211354693648116),
#  'makes': (1, 0.056211354693648116),
#  'man': (6, 0.33726812816188867),
#  'many': (1, 0.056211354693648116),
#  "many's": (1, 0.056211354693648116),
#  'marbles': (1, 0.056211354693648116),
#  'master': (2, 0.11242270938729623),
#  'mastered': (1, 0.056211354693648116),
#  'matches': (1, 0.056211354693648116),
#  'mathematicians': (1, 0.056211354693648116),
#  'mathematics': (2, 0.11242270938729623),
#  'may': (1, 0.056211354693648116),
#  'me': (4, 0.22484541877459246),
#  'medicine': (1, 0.056211354693648116),
#  'melancholy': (2, 0.11242270938729623),
#  'men': (4, 0.22484541877459246),
#  'mere': (1, 0.056211354693648116),
#  'might': (4, 0.22484541877459246),
#  'mind': (1, 0.056211354693648116),
#  'mistake': (2, 0.11242270938729623),
#  'moment': (1, 0.056211354693648116),
#  'money': (4, 0.22484541877459246),
#  'monosyllables': (1, 0.056211354693648116),
#  'moody': (1, 0.056211354693648116),
#  'more': (4, 0.22484541877459246),
#  'motion': (1, 0.056211354693648116),
#  'mr': (1, 0.056211354693648116),
#  'much': (3, 0.16863406408094433),
#  'murmured': (1, 0.056211354693648116),
#  'my': (2, 0.11242270938729623),
#  'mysterious': (1, 0.056211354693648116),
#  'mystery': (1, 0.056211354693648116),
#  'n': (1, 0.056211354693648116),
#  'names': (2, 0.11242270938729623),
#  'near': (1, 0.056211354693648116),
#  'nervous': (1, 0.056211354693648116),
#  'never': (4, 0.22484541877459246),
#  'next': (1, 0.056211354693648116),
#  'night': (1, 0.056211354693648116),
#  'ninety-six': (1, 0.056211354693648116),
#  'no': (4, 0.22484541877459246),
#  'nor': (1, 0.056211354693648116),
#  'not': (2, 0.11242270938729623),
#  'nothing': (1, 0.056211354693648116),
#  'noticed': (1, 0.056211354693648116),
#  'now': (6, 0.33726812816188867),
#  'nowadays': (1, 0.056211354693648116),
#  'nurse': (1, 0.056211354693648116),
#  'o': (1, 0.056211354693648116),
#  'occasionally': (1, 0.056211354693648116),
#  'occupation': (1, 0.056211354693648116),
#  'occupations': (1, 0.056211354693648116),
#  'of': (53, 2.9792017987633503),
#  'offering': (1, 0.056211354693648116),
#  'often': (2, 0.11242270938729623),
#  'old': (6, 0.33726812816188867),
#  'older': (1, 0.056211354693648116),
#  'omitted': (1, 0.056211354693648116),
#  'on': (16, 0.8993816750983699),
#  'one': (11, 0.6183249016301293),
#  'only': (4, 0.22484541877459246),
#  'or': (12, 0.6745362563237773),
#  'ordinary': (1, 0.056211354693648116),
#  'others': (2, 0.11242270938729623),
#  'out': (1, 0.056211354693648116),
#  'over': (1, 0.056211354693648116),
#  'owing': (1, 0.056211354693648116),
#  'own': (1, 0.056211354693648116),
#  'pages': (1, 0.056211354693648116),
#  'panting': (1, 0.056211354693648116),
#  'parallelopiped': (1, 0.056211354693648116),
#  'partnership': (1, 0.056211354693648116),
#  'passionate': (1, 0.056211354693648116),
#  'passions': (1, 0.056211354693648116),
#  'people': (3, 0.16863406408094433),
#  'perhaps': (1, 0.056211354693648116),
#  'peril': (1, 0.056211354693648116),
#  'phenomenal': (1, 0.056211354693648116),
#  'physical': (1, 0.056211354693648116),
#  'piece': (3, 0.16863406408094433),
#  'pile': (3, 0.16863406408094433),
#  'piling': (1, 0.056211354693648116),
#  'pitiful': (1, 0.056211354693648116),
#  'plain': (2, 0.11242270938729623),
#  'plaintive': (1, 0.056211354693648116),
#  'plot': (1, 0.056211354693648116),
#  'poor': (1, 0.056211354693648116),
#  'possibly': (1, 0.056211354693648116),
#  'power': (1, 0.056211354693648116),
#  'precarious': (1, 0.056211354693648116),
#  'prefer': (1, 0.056211354693648116),
#  'presented': (1, 0.056211354693648116),
#  'presently': (2, 0.11242270938729623),
#  'preyed': (1, 0.056211354693648116),
#  'problem': (1, 0.056211354693648116),
#  'problems': (2, 0.11242270938729623),
#  'proposes': (1, 0.056211354693648116),
#  'propositions': (1, 0.056211354693648116),
#  'pump': (4, 0.22484541877459246),
#  'pumping': (2, 0.11242270938729623),
#  'put': (3, 0.16863406408094433),
#  'question': (1, 0.056211354693648116),
#  'questions': (1, 0.056211354693648116),
#  'quiet': (1, 0.056211354693648116),
#  'quite': (1, 0.056211354693648116),
#  'race': (1, 0.056211354693648116),
#  'racing': (2, 0.11242270938729623),
#  'raise': (1, 0.056211354693648116),
#  'rallied': (1, 0.056211354693648116),
#  'rapidly': (2, 0.11242270938729623),
#  'rate."--the': (1, 0.056211354693648116),
#  'realizing': (1, 0.056211354693648116),
#  'really': (1, 0.056211354693648116),
#  'recovered': (1, 0.056211354693648116),
#  'reduce': (1, 0.056211354693648116),
#  'refused': (1, 0.056211354693648116),
#  'regatta': (1, 0.056211354693648116),
#  'regattas': (1, 0.056211354693648116),
#  'regular': (1, 0.056211354693648116),
#  'remains': (1, 0.056211354693648116),
#  'removed': (1, 0.056211354693648116),
#  'repeating': (1, 0.056211354693648116),
#  'resemblance': (1, 0.056211354693648116),
#  'rest': (1, 0.056211354693648116),
#  'return': (1, 0.056211354693648116),
#  'revel': (1, 0.056211354693648116),
#  'rides': (1, 0.056211354693648116),
#  'right': (1, 0.056211354693648116),
#  'river': (1, 0.056211354693648116),
#  'robinson': (1, 0.056211354693648116),
#  'romance': (1, 0.056211354693648116),
#  'romantic': (1, 0.056211354693648116),
#  'room': (1, 0.056211354693648116),
#  'roughly': (1, 0.056211354693648116),
#  'row': (2, 0.11242270938729623),
#  'rowing': (4, 0.22484541877459246),
#  'ruined': (1, 0.056211354693648116),
#  'rules': (1, 0.056211354693648116),
#  'running': (1, 0.056211354693648116),
#  'sable': (1, 0.056211354693648116),
#  'said': (8, 0.44969083754918493),
#  'same': (2, 0.11242270938729623),
#  'sarcophagus': (1, 0.056211354693648116),
#  'sat': (2, 0.11242270938729623),
#  'saved': (1, 0.056211354693648116),
#  'saw': (1, 0.056211354693648116),
#  'say': (3, 0.16863406408094433),
#  'says': (1, 0.056211354693648116),
#  'scratch': (1, 0.056211354693648116),
#  'see': (2, 0.11242270938729623),
#  'seems': (2, 0.11242270938729623),
#  'seen': (1, 0.056211354693648116),
#  'set': (1, 0.056211354693648116),
#  'settled': (1, 0.056211354693648116),
#  'shadows': (1, 0.056211354693648116),
#  'shakes': (1, 0.056211354693648116),
#  'shame': (1, 0.056211354693648116),
#  'shock': (1, 0.056211354693648116),
#  'shook': (1, 0.056211354693648116),
#  'short': (1, 0.056211354693648116),
#  'shouted': (1, 0.056211354693648116),
#  'shown': (1, 0.056211354693648116),
#  'sides': (1, 0.056211354693648116),
#  'sight': (1, 0.056211354693648116),
#  'sign': (1, 0.056211354693648116),
#  'since': (1, 0.056211354693648116),
#  'sir': (3, 0.16863406408094433),
#  'sir--just': (1, 0.056211354693648116),
#  'sleep': (1, 0.056211354693648116),
#  'sleeping': (1, 0.056211354693648116),
#  'sly': (1, 0.056211354693648116),
#  'smiled': (1, 0.056211354693648116),
#  'smith': (2, 0.11242270938729623),
#  'smoke': (1, 0.056211354693648116),
#  'so': (2, 0.11242270938729623),
#  'sobbed': (1, 0.056211354693648116),
#  'sofa': (1, 0.056211354693648116),
#  'some': (2, 0.11242270938729623),
#  'something': (1, 0.056211354693648116),
#  'soon': (2, 0.11242270938729623),
#  'sort': (1, 0.056211354693648116),
#  'soul': (1, 0.056211354693648116),
#  'sound': (1, 0.056211354693648116),
#  'sped': (1, 0.056211354693648116),
#  'spelling': (1, 0.056211354693648116),
#  'spoke': (2, 0.11242270938729623),
#  'sporting': (1, 0.056211354693648116),
#  'sports': (1, 0.056211354693648116),
#  'stage-coaches': (1, 0.056211354693648116),
#  'stand': (1, 0.056211354693648116),
#  'started': (1, 0.056211354693648116),
#  'statement': (1, 0.056211354693648116),
#  'stiff': (1, 0.056211354693648116),
#  'still': (1, 0.056211354693648116),
#  'stood': (2, 0.11242270938729623),
#  'stories': (1, 0.056211354693648116),
#  'strength': (2, 0.11242270938729623),
#  'stretch': (1, 0.056211354693648116),
#  'striven': (1, 0.056211354693648116),
#  'strong': (1, 0.056211354693648116),
#  'strong-willed': (1, 0.056211354693648116),
#  'student': (1, 0.056211354693648116),
#  'stumbled': (1, 0.056211354693648116),
#  'submitted': (1, 0.056211354693648116),
#  'successfully': (1, 0.056211354693648116),
#  'sum': (1, 0.056211354693648116),
#  'sums': (1, 0.056211354693648116),
#  'sun': (1, 0.056211354693648116),
#  'sunk': (1, 0.056211354693648116),
#  'surprised': (1, 0.056211354693648116),
#  'surrounded': (1, 0.056211354693648116),
#  'swim': (1, 0.056211354693648116),
#  'swimming': (1, 0.056211354693648116),
#  'swiss': (1, 0.056211354693648116),
#  'syllable': (1, 0.056211354693648116),
#  'symbols': (1, 0.056211354693648116),
#  'system': (1, 0.056211354693648116),
#  'taken': (2, 0.11242270938729623),
#  'takes': (1, 0.056211354693648116),
#  'tasks': (1, 0.056211354693648116),
#  'tea': (1, 0.056211354693648116),
#  'tears': (1, 0.056211354693648116),
#  'tell': (1, 0.056211354693648116),
#  'temperament': (1, 0.056211354693648116),
#  'terms': (1, 0.056211354693648116),
#  'than': (4, 0.22484541877459246),
#  'that': (19, 1.0680157391793141),
#  "that'll": (1, 0.056211354693648116),
#  'the': (84, 4.721753794266442),
#  'their': (8, 0.44969083754918493),
#  'them': (8, 0.44969083754918493),
#  'themselves': (1, 0.056211354693648116),
#  'then': (5, 0.2810567734682406),
#  'these': (4, 0.22484541877459246),
#  'they': (21, 1.1804384485666104),
#  'things': (1, 0.056211354693648116),
#  'think': (4, 0.22484541877459246),
#  'this': (5, 0.2810567734682406),
#  'thoroughly': (1, 0.056211354693648116),
#  'though': (3, 0.16863406408094433),
#  'three': (3, 0.16863406408094433),
#  'through': (2, 0.11242270938729623),
#  'thus': (1, 0.056211354693648116),
#  'time': (2, 0.11242270938729623),
#  'times': (4, 0.22484541877459246),
#  'tire': (1, 0.056211354693648116),
#  'to': (33, 1.854974704890388),
#  'to-morrow': (1, 0.056211354693648116),
#  'to-night': (1, 0.056211354693648116),
#  'together': (1, 0.056211354693648116),
#  'told': (1, 0.056211354693648116),
#  'too': (2, 0.11242270938729623),
#  'town': (2, 0.11242270938729623),
#  'transpired': (1, 0.056211354693648116),
#  'turn': (1, 0.056211354693648116),
#  'twice': (1, 0.056211354693648116),
#  'two': (6, 0.33726812816188867),
#  'unbroken': (1, 0.056211354693648116),
#  'under': (1, 0.056211354693648116),
#  'undersized': (1, 0.056211354693648116),
#  'unostentatious': (1, 0.056211354693648116),
#  'until': (1, 0.056211354693648116),
#  'up': (6, 0.33726812816188867),
#  'upon': (2, 0.11242270938729623),
#  'us': (2, 0.11242270938729623),
#  'use': (1, 0.056211354693648116),
#  'used': (4, 0.22484541877459246),
#  'varied': (1, 0.056211354693648116),
#  'vehicles': (1, 0.056211354693648116),
#  'very': (1, 0.056211354693648116),
#  'view': (1, 0.056211354693648116),
#  'voluntarily': (1, 0.056211354693648116),
#  'wager': (2, 0.11242270938729623),
#  'walk': (3, 0.16863406408094433),
#  'walker': (1, 0.056211354693648116),
#  'walking': (2, 0.11242270938729623),
#  'walking-matches--a': (1, 0.056211354693648116),
#  'was': (18, 1.0118043844856661),
#  'watched': (2, 0.11242270938729623),
#  'water': (2, 0.11242270938729623),
#  'water-tight': (1, 0.056211354693648116),
#  'we': (1, 0.056211354693648116),
#  "we're": (1, 0.056211354693648116),
#  "we've": (1, 0.056211354693648116),
#  'weaker-minded': (1, 0.056211354693648116),
#  'weakling': (1, 0.056211354693648116),
#  'wear': (1, 0.056211354693648116),
#  'went': (1, 0.056211354693648116),
#  'were': (2, 0.11242270938729623),
#  'whatever': (1, 0.056211354693648116),
#  'when': (1, 0.056211354693648116),
#  'where': (1, 0.056211354693648116),
#  'which': (4, 0.22484541877459246),
#  'whispered': (1, 0.056211354693648116),
#  'who': (4, 0.22484541877459246),
#  'whose': (1, 0.056211354693648116),
#  'why': (1, 0.056211354693648116),
#  'will': (1, 0.056211354693648116),
#  'william': (1, 0.056211354693648116),
#  'wins': (1, 0.056211354693648116),
#  'wise': (1, 0.056211354693648116),
#  'with': (14, 0.7869589657110737),
#  'without': (3, 0.16863406408094433),
#  "won't": (1, 0.056211354693648116),
#  'wood': (4, 0.22484541877459246),
#  'words': (2, 0.11242270938729623),
#  'work': (11, 0.6183249016301293),
#  'working': (1, 0.056211354693648116),
#  'worn': (1, 0.056211354693648116),
#  'wrangle': (1, 0.056211354693648116),
#  'writing': (1, 0.056211354693648116),
#  'x': (1, 0.056211354693648116),
#  'y': (1, 0.056211354693648116),
#  'yards': (1, 0.056211354693648116),
#  'years': (1, 0.056211354693648116),
#  'you': (8, 0.44969083754918493),
#  "you'll": (1, 0.056211354693648116),
#  "you've": (1, 0.056211354693648116),
#  'your': (2, 0.11242270938729623),
#  'z': (1, 0.056211354693648116)}

# %% [markdown]
# ### 3. Upravte předchozí program tak, aby nerozlišoval mezi malými a velkými písmeny.

# %%
# TODO: Implement your solution.

# %% [markdown]
# ### 4. Obměňte první program tak, aby ukládal počet výskytů nikoli písmen, ale slov.
#
# **Hint:** Dejte si pozor na to, že např. ahoj a ahoj! by mělo být to samé slovo. Zřejmě se to tedy bude chtít nějak zbavit interpunkce a dalších věcí. S výhodou můžete použít konstantu string.punctuation .

# %%
# TODO: Implement your solution.
from pprint import pprint
import string
# TODO: Implement your solution.
dic = {}
with open("leacock-abc.txt") as f:
    for x in f:
        for g in x.lower().split():
            g = g.strip(string.punctuation)
            if dic.get(g) is None:
                dic[g] = 1
            else:
                dic[g] += 1
            
pprint(dic)
# Out:
# {'a': 76,
#  "a's": 1,
#  'abjured': 1,
#  'about': 3,
#  'above': 1,
#  'absence': 1,
#  'accidentally': 1,
#  'accustomed': 1,
#  'acquaintances': 1,
#  'actual': 1,
#  'admiration': 1,
#  'adventure': 1,
#  'affected': 1,
#  'afraid': 1,
#  'after': 7,
#  'again': 2,
#  'again."--the': 1,
#  'aged': 1,
#  'aggravated': 1,
#  'aimlessly': 1,
#  'alarmed': 1,
#  'algebra': 1,
#  'algebraica': 1,
#  'all': 5,
#  'alpha': 1,
#  'also': 1,
#  'always': 3,
#  'ambitions': 1,
#  'an': 5,
#  'and': 80,
#  'answer': 1,
#  'answered': 2,
#  'any': 2,
#  'appear': 1,
#  'aquatic': 1,
#  'arduous': 1,
#  'are': 9,
#  'arithmetic': 2,
#  'arithmetics': 1,
#  'arms': 1,
#  'arrived': 1,
#  'art': 1,
#  'as': 26,
#  'asked': 1,
#  'aspirations': 1,
#  'associates': 1,
#  'asylum': 1,
#  'at': 11,
#  'aught': 1,
#  'away': 1,
#  'b': 28,
#  'badly': 1,
#  'bank': 2,
#  'be': 2,
#  'beat': 1,
#  'became': 5,
#  'become': 2,
#  'bed': 3,
#  'been': 7,
#  'beginner': 1,
#  'being': 1,
#  'bends': 1,
#  'best': 1,
#  'bet': 2,
#  'beta': 1,
#  'betraying': 1,
#  'bets': 2,
#  'bets.--b': 1,
#  'bicycle': 2,
#  'bit': 2,
#  'blood': 1,
#  'blunder': 1,
#  'blustering': 2,
#  'book': 1,
#  'bore': 1,
#  'borrows': 1,
#  'both': 2,
#  'bottom': 1,
#  'bowed': 1,
#  'box': 1,
#  'bracket': 2,
#  'brackets': 1,
#  'breathing': 1,
#  'broken': 2,
#  'brotherly': 1,
#  'bullied': 1,
#  'burst': 1,
#  'busy': 1,
#  'but': 9,
#  'by': 5,
#  'c': 32,
#  "c's": 3,
#  'called': 4,
#  'came': 3,
#  'can': 11,
#  'capital': 1,
#  'case': 1,
#  'cemetery': 2,
#  'certain': 5,
#  'challenges': 1,
#  'chanced': 1,
#  'changed': 1,
#  'changing': 1,
#  'chapters': 1,
#  'characters': 1,
#  'charm': 1,
#  'christian': 1,
#  'cistern': 3,
#  'cisterns': 2,
#  'clear': 1,
#  'clearly': 1,
#  'clothes': 1,
#  'come': 2,
#  'commercial': 1,
#  'common': 1,
#  'competes': 1,
#  'concealed': 1,
#  'condition': 1,
#  'confronted': 1,
#  'consented': 1,
#  'constant': 1,
#  'constantly': 1,
#  'containing': 1,
#  'contented': 1,
#  'cord': 2,
#  'cottage': 1,
#  'coughing': 1,
#  'could': 3,
#  'countless': 1,
#  'course': 2,
#  'creatures': 1,
#  'current': 1,
#  'd': 2,
#  'dallying': 1,
#  'day': 2,
#  'dead': 1,
#  'death': 2,
#  'decimal': 1,
#  'deepened': 1,
#  'deference': 1,
#  'define': 1,
#  'delta': 1,
#  'denominator': 1,
#  'deranged': 1,
#  'devoted': 1,
#  'did': 2,
#  'differed': 1,
#  'difficulty': 1,
#  'dig': 5,
#  'digging': 2,
#  'digs': 1,
#  'dirty': 1,
#  'disease': 1,
#  'distance': 1,
#  'ditch': 1,
#  'ditch-digging': 1,
#  'ditches': 1,
#  'division': 1,
#  'do': 6,
#  'doctor': 3,
#  'doing': 1,
#  "don't": 1,
#  'done': 1,
#  'down': 1,
#  'downstairs': 1,
#  'draught': 2,
#  'drink': 1,
#  'driven': 1,
#  'driving': 2,
#  'dug': 1,
#  'dying': 1,
#  'early': 1,
#  'easy-going': 1,
#  'eating': 1,
#  'element': 2,
#  'em': 2,
#  'employed': 1,
#  'employing': 1,
#  'empty': 1,
#  'end': 4,
#  'endurance': 1,
#  'energetic': 1,
#  'engage': 1,
#  'engaged': 1,
#  'entered': 1,
#  'etc': 2,
#  'euclid': 1,
#  'euclid.--it': 1,
#  'even': 2,
#  'evening': 2,
#  'ever': 3,
#  'everything': 1,
#  'except': 1,
#  'expanse': 1,
#  'expired': 1,
#  'face': 1,
#  'fact': 1,
#  'fagged': 1,
#  'family': 2,
#  'far': 1,
#  'fashion': 1,
#  'fast': 6,
#  'faster': 1,
#  'fatal': 1,
#  'feebly': 1,
#  'feel': 1,
#  'fellow': 3,
#  'fellows': 2,
#  'fetch': 3,
#  'figures': 1,
#  'filling': 1,
#  'finally': 1,
#  'find': 5,
#  'finds': 1,
#  'fine': 1,
#  'firmly': 1,
#  'first': 4,
#  'fit': 1,
#  'fix': 1,
#  'flared': 1,
#  'flesh': 1,
#  'flight': 1,
#  'flood': 1,
#  'followed': 1,
#  'foot': 1,
#  'for': 9,
#  'foreigners': 1,
#  'form': 1,
#  'former': 1,
#  'forth': 1,
#  'fortnight': 1,
#  'forty-eight': 1,
#  'found': 2,
#  'four': 7,
#  'fractions': 1,
#  'frail': 1,
#  'frenzy': 1,
#  'friend': 1,
#  'from': 6,
#  'front': 1,
#  'full': 2,
#  'full-blooded': 1,
#  'funeral': 1,
#  'gamma': 1,
#  'garden': 3,
#  'garrulous': 1,
#  'gave': 1,
#  'generally': 1,
#  'generously': 1,
#  'gentle': 1,
#  'get': 2,
#  'getting': 1,
#  'give': 1,
#  'go': 1,
#  'going': 4,
#  'good': 2,
#  'grave': 1,
#  'great': 1,
#  'grew': 1,
#  'grief': 1,
#  'grow': 1,
#  'growl': 1,
#  'had': 8,
#  'half': 1,
#  'hamlin': 2,
#  'hand': 1,
#  'handicap': 1,
#  'hardly': 1,
#  'has': 9,
#  'have': 2,
#  'having': 2,
#  'he': 25,
#  "he's": 1,
#  'head': 2,
#  'health': 1,
#  'heard': 4,
#  'hearse': 1,
#  'hearses': 1,
#  'heave': 1,
#  'heavenward': 1,
#  'help': 1,
#  'helpless': 1,
#  'henry': 1,
#  'here': 3,
#  'him': 8,
#  'himself': 2,
#  'his': 22,
#  'historical': 1,
#  'history': 2,
#  'hoeing': 1,
#  'holes': 1,
#  'home': 2,
#  'horseback': 1,
#  'hot': 1,
#  'hot-headed': 1,
#  'hour': 4,
#  'hours': 2,
#  'how': 4,
#  'however': 1,
#  'human': 1,
#  'hundred': 1,
#  'i': 28,
#  "i'll": 2,
#  "i'm": 4,
#  'identity': 1,
#  'if': 3,
#  'ill': 2,
#  'ill-fated': 1,
#  'in': 50,
#  'incarcerated': 1,
#  'indifferent': 1,
#  'industry': 1,
#  'inquiry': 1,
#  'intellect': 1,
#  'interest': 2,
#  'into': 3,
#  'is': 14,
#  "isn't": 1,
#  'it': 17,
#  'its': 1,
#  'job': 2,
#  'jobs': 1,
#  'john': 1,
#  'joyless': 1,
#  'just': 2,
#  'keep': 1,
#  'kill': 1,
#  'kind-heartedness-like': 1,
#  'know': 3,
#  'knowed': 1,
#  'known': 2,
#  'labour': 1,
#  'laboured': 1,
#  'labouring': 1,
#  'lacking': 1,
#  'lad': 1,
#  'languidly': 1,
#  'last': 2,
#  'lays': 1,
#  'leak': 2,
#  'leaks': 1,
#  'learned': 1,
#  'left': 2,
#  'leisure': 1,
#  'let': 1,
#  'life': 3,
#  'like': 1,
#  'line': 1,
#  'little': 7,
#  'live': 1,
#  'living': 1,
#  'locomotive': 1,
#  'locomotives': 1,
#  'logarithm': 1,
#  'long': 3,
#  'longer': 1,
#  'look': 1,
#  'looked': 1,
#  'lost': 3,
#  'lowered': 1,
#  'lowest': 1,
#  'lying': 1,
#  'm': 1,
#  'made': 1,
#  'makes': 1,
#  'man': 6,
#  'many': 1,
#  "many's": 1,
#  'marbles': 1,
#  'master': 2,
#  'mastered': 1,
#  'matches': 1,
#  'mathematicians': 1,
#  'mathematics': 2,
#  'may': 1,
#  'me': 4,
#  'medicine': 1,
#  'melancholy': 2,
#  'men': 4,
#  'mere': 1,
#  'might': 4,
#  'mind': 1,
#  'mistake': 2,
#  'moment': 1,
#  'money': 4,
#  'monosyllables': 1,
#  'moody': 1,
#  'more': 4,
#  'motion': 1,
#  'mr': 1,
#  'much': 3,
#  'murmured': 1,
#  'my': 2,
#  'mysterious': 1,
#  'mystery': 1,
#  'n': 1,
#  'names': 2,
#  'near': 1,
#  'nervous': 1,
#  'never': 4,
#  'next': 1,
#  'night': 1,
#  'ninety-six': 1,
#  'no': 4,
#  'nor': 1,
#  'not': 2,
#  'nothing': 1,
#  'noticed': 1,
#  'now': 6,
#  'nowadays': 1,
#  'nurse': 1,
#  'o': 1,
#  'occasionally': 1,
#  'occupation': 1,
#  'occupations': 1,
#  'of': 53,
#  'offering': 1,
#  'often': 2,
#  'old': 6,
#  'older': 1,
#  'omitted': 1,
#  'on': 16,
#  'one': 11,
#  'only': 4,
#  'or': 12,
#  'ordinary': 1,
#  'others': 2,
#  'out': 1,
#  'over': 1,
#  'owing': 1,
#  'own': 1,
#  'pages': 1,
#  'panting': 1,
#  'parallelopiped': 1,
#  'partnership': 1,
#  'passionate': 1,
#  'passions': 1,
#  'people': 3,
#  'perhaps': 1,
#  'peril': 1,
#  'phenomenal': 1,
#  'physical': 1,
#  'piece': 3,
#  'pile': 3,
#  'piling': 1,
#  'pitiful': 1,
#  'plain': 2,
#  'plaintive': 1,
#  'plot': 1,
#  'poor': 1,
#  'possibly': 1,
#  'power': 1,
#  'precarious': 1,
#  'prefer': 1,
#  'presented': 1,
#  'presently': 2,
#  'preyed': 1,
#  'problem': 1,
#  'problems': 2,
#  'proposes': 1,
#  'propositions': 1,
#  'pump': 4,
#  'pumping': 2,
#  'put': 3,
#  'question': 1,
#  'questions': 1,
#  'quiet': 1,
#  'quite': 1,
#  'race': 1,
#  'racing': 2,
#  'raise': 1,
#  'rallied': 1,
#  'rapidly': 2,
#  'rate."--the': 1,
#  'realizing': 1,
#  'really': 1,
#  'recovered': 1,
#  'reduce': 1,
#  'refused': 1,
#  'regatta': 1,
#  'regattas': 1,
#  'regular': 1,
#  'remains': 1,
#  'removed': 1,
#  'repeating': 1,
#  'resemblance': 1,
#  'rest': 1,
#  'return': 1,
#  'revel': 1,
#  'rides': 1,
#  'right': 1,
#  'river': 1,
#  'robinson': 1,
#  'romance': 1,
#  'romantic': 1,
#  'room': 1,
#  'roughly': 1,
#  'row': 2,
#  'rowing': 4,
#  'ruined': 1,
#  'rules': 1,
#  'running': 1,
#  'sable': 1,
#  'said': 8,
#  'same': 2,
#  'sarcophagus': 1,
#  'sat': 2,
#  'saved': 1,
#  'saw': 1,
#  'say': 3,
#  'says': 1,
#  'scratch': 1,
#  'see': 2,
#  'seems': 2,
#  'seen': 1,
#  'set': 1,
#  'settled': 1,
#  'shadows': 1,
#  'shakes': 1,
#  'shame': 1,
#  'shock': 1,
#  'shook': 1,
#  'short': 1,
#  'shouted': 1,
#  'shown': 1,
#  'sides': 1,
#  'sight': 1,
#  'sign': 1,
#  'since': 1,
#  'sir': 3,
#  'sir--just': 1,
#  'sleep': 1,
#  'sleeping': 1,
#  'sly': 1,
#  'smiled': 1,
#  'smith': 2,
#  'smoke': 1,
#  'so': 2,
#  'sobbed': 1,
#  'sofa': 1,
#  'some': 2,
#  'something': 1,
#  'soon': 2,
#  'sort': 1,
#  'soul': 1,
#  'sound': 1,
#  'sped': 1,
#  'spelling': 1,
#  'spoke': 2,
#  'sporting': 1,
#  'sports': 1,
#  'stage-coaches': 1,
#  'stand': 1,
#  'started': 1,
#  'statement': 1,
#  'stiff': 1,
#  'still': 1,
#  'stood': 2,
#  'stories': 1,
#  'strength': 2,
#  'stretch': 1,
#  'striven': 1,
#  'strong': 1,
#  'strong-willed': 1,
#  'student': 1,
#  'stumbled': 1,
#  'submitted': 1,
#  'successfully': 1,
#  'sum': 1,
#  'sums': 1,
#  'sun': 1,
#  'sunk': 1,
#  'surprised': 1,
#  'surrounded': 1,
#  'swim': 1,
#  'swimming': 1,
#  'swiss': 1,
#  'syllable': 1,
#  'symbols': 1,
#  'system': 1,
#  'taken': 2,
#  'takes': 1,
#  'tasks': 1,
#  'tea': 1,
#  'tears': 1,
#  'tell': 1,
#  'temperament': 1,
#  'terms': 1,
#  'than': 4,
#  'that': 19,
#  "that'll": 1,
#  'the': 84,
#  'their': 8,
#  'them': 8,
#  'themselves': 1,
#  'then': 5,
#  'these': 4,
#  'they': 21,
#  'things': 1,
#  'think': 4,
#  'this': 5,
#  'thoroughly': 1,
#  'though': 3,
#  'three': 3,
#  'through': 2,
#  'thus': 1,
#  'time': 2,
#  'times': 4,
#  'tire': 1,
#  'to': 33,
#  'to-morrow': 1,
#  'to-night': 1,
#  'together': 1,
#  'told': 1,
#  'too': 2,
#  'town': 2,
#  'transpired': 1,
#  'turn': 1,
#  'twice': 1,
#  'two': 6,
#  'unbroken': 1,
#  'under': 1,
#  'undersized': 1,
#  'unostentatious': 1,
#  'until': 1,
#  'up': 6,
#  'upon': 2,
#  'us': 2,
#  'use': 1,
#  'used': 4,
#  'varied': 1,
#  'vehicles': 1,
#  'very': 1,
#  'view': 1,
#  'voluntarily': 1,
#  'wager': 2,
#  'walk': 3,
#  'walker': 1,
#  'walking': 2,
#  'walking-matches--a': 1,
#  'was': 18,
#  'watched': 2,
#  'water': 2,
#  'water-tight': 1,
#  'we': 1,
#  "we're": 1,
#  "we've": 1,
#  'weaker-minded': 1,
#  'weakling': 1,
#  'wear': 1,
#  'went': 1,
#  'were': 2,
#  'whatever': 1,
#  'when': 1,
#  'where': 1,
#  'which': 4,
#  'whispered': 1,
#  'who': 4,
#  'whose': 1,
#  'why': 1,
#  'will': 1,
#  'william': 1,
#  'wins': 1,
#  'wise': 1,
#  'with': 14,
#  'without': 3,
#  "won't": 1,
#  'wood': 4,
#  'words': 2,
#  'work': 11,
#  'working': 1,
#  'worn': 1,
#  'wrangle': 1,
#  'writing': 1,
#  'x': 1,
#  'y': 1,
#  'yards': 1,
#  'years': 1,
#  'you': 8,
#  "you'll": 1,
#  "you've": 1,
#  'your': 2,
#  'z': 1}

# %%
# TODO: Implement your solution.
sorted(dic, key=lambda x: dic[x], reverse=True)
# Out:
# ['the',
#  'and',
#  'a',
#  'of',
#  'in',
#  'to',
#  'c',
#  'b',
#  'i',
#  'as',
#  'he',
#  'his',
#  'they',
#  'that',
#  'was',
#  'it',
#  'on',
#  'with',
#  'is',
#  'or',
#  'work',
#  'can',
#  'one',
#  'at',
#  'has',
#  'are',
#  'but',
#  'for',
#  'them',
#  'their',
#  'him',
#  'said',
#  'had',
#  'you',
#  'four',
#  'after',
#  'been',
#  'little',
#  'do',
#  'two',
#  'fast',
#  'old',
#  'now',
#  'man',
#  'up',
#  'from',
#  'by',
#  'an',
#  'certain',
#  'this',
#  'find',
#  'dig',
#  'became',
#  'all',
#  'then',
#  'who',
#  'first',
#  'money',
#  'these',
#  'end',
#  'called',
#  'hour',
#  'how',
#  'than',
#  'only',
#  'more',
#  'wood',
#  'times',
#  'pump',
#  'which',
#  'men',
#  'might',
#  'rowing',
#  'never',
#  'heard',
#  'me',
#  'think',
#  'used',
#  'no',
#  "i'm",
#  'going',
#  'though',
#  'without',
#  'three',
#  'people',
#  'piece',
#  'much',
#  'long',
#  'walk',
#  'into',
#  'if',
#  'put',
#  'always',
#  'cistern',
#  'fellow',
#  'life',
#  'lost',
#  'ever',
#  'could',
#  'say',
#  'came',
#  'garden',
#  'know',
#  'about',
#  'sir',
#  'here',
#  'bed',
#  'pile',
#  'fetch',
#  'doctor',
#  "c's",
#  'element',
#  'mathematics',
#  'arithmetic',
#  'himself',
#  'known',
#  'problems',
#  'family',
#  'not',
#  'etc',
#  'wager',
#  'again',
#  'so',
#  'found',
#  'too',
#  'job',
#  'walking',
#  'cord',
#  'having',
#  'bicycle',
#  'row',
#  'become',
#  'water',
#  'cisterns',
#  'leak',
#  'through',
#  'course',
#  'good',
#  'names',
#  'often',
#  'same',
#  'history',
#  'watched',
#  'hours',
#  'full',
#  'us',
#  'blustering',
#  'bets',
#  'others',
#  'strength',
#  'mistake',
#  'digging',
#  'pumping',
#  'broken',
#  'hamlin',
#  'smith',
#  'time',
#  'evening',
#  'come',
#  "i'll",
#  'get',
#  'some',
#  'just',
#  'fellows',
#  'bet',
#  'both',
#  'your',
#  'presently',
#  'see',
#  'town',
#  'any',
#  'home',
#  'my',
#  'were',
#  'day',
#  'upon',
#  'd',
#  'be',
#  'did',
#  'em',
#  'answered',
#  'master',
#  'racing',
#  'plain',
#  'bit',
#  'melancholy',
#  'soon',
#  'left',
#  'taken',
#  'ill',
#  'seems',
#  'bank',
#  'sat',
#  'draught',
#  'even',
#  'have',
#  'stood',
#  'head',
#  'bracket',
#  'rapidly',
#  'last',
#  'driving',
#  'cemetery',
#  'death',
#  'interest',
#  'spoke',
#  'words',
#  'human',
#  'student',
#  'mastered',
#  'rules',
#  'art',
#  'successfully',
#  'striven',
#  'sums',
#  'fractions',
#  'finds',
#  'confronted',
#  'unbroken',
#  'expanse',
#  'questions',
#  'short',
#  'stories',
#  'adventure',
#  'industry',
#  'omitted',
#  'betraying',
#  'strong',
#  'resemblance',
#  'romance',
#  'characters',
#  'plot',
#  'problem',
#  'form',
#  'question',
#  'generally',
#  'sort',
#  'thus',
#  'employed',
#  'ditch',
#  'twice',
#  'wise',
#  'lays',
#  'faster',
#  'half',
#  'indifferent',
#  'walker',
#  'far',
#  'forth',
#  'occupations',
#  'many',
#  'varied',
#  'older',
#  'arithmetics',
#  'contented',
#  'themselves',
#  'doing',
#  'statement',
#  'case',
#  'however',
#  'sly',
#  'mysterious',
#  'possibly',
#  'lacking',
#  'romantic',
#  'charm',
#  'fashion',
#  'define',
#  'clearly',
#  'set',
#  'matches',
#  'ditch-digging',
#  'regattas',
#  'piling',
#  'commercial',
#  'entered',
#  'partnership',
#  'mystery',
#  'capital',
#  'above',
#  'revel',
#  'motion',
#  'when',
#  'tire',
#  'walking-matches--a',
#  'rides',
#  'horseback',
#  'borrows',
#  'competes',
#  'weaker-minded',
#  'associates',
#  'foot',
#  'race',
#  'locomotives',
#  'historical',
#  'engage',
#  'stage-coaches',
#  'aquatic',
#  'swim',
#  'occupation',
#  'actual',
#  'prefer',
#  'holes',
#  'bottom',
#  'water-tight',
#  'also',
#  'takes',
#  'best',
#  'locomotive',
#  'right',
#  'swimming',
#  'current',
#  'whatever',
#  'being',
#  'sports',
#  'wins',
#  'early',
#  'chapters',
#  'identity',
#  'concealed',
#  'under',
#  'john',
#  'william',
#  'henry',
#  'wrangle',
#  'over',
#  'division',
#  'marbles',
#  'algebra',
#  'x',
#  'y',
#  'z',
#  'christian',
#  'really',
#  'followed',
#  'countless',
#  'pages',
#  'leisure',
#  'dallying',
#  'seen',
#  'panting',
#  'sides',
#  'heave',
#  'frenzy',
#  'filling',
#  'something',
#  'mere',
#  'symbols',
#  'appear',
#  'creatures',
#  'flesh',
#  'blood',
#  'living',
#  'own',
#  'passions',
#  'ambitions',
#  'aspirations',
#  'like',
#  'rest',
#  'let',
#  'view',
#  'turn',
#  'full-blooded',
#  'energetic',
#  'temperament',
#  'hot-headed',
#  'strong-willed',
#  'proposes',
#  'everything',
#  'challenges',
#  'makes',
#  'bends',
#  'will',
#  'great',
#  'physical',
#  'phenomenal',
#  'endurance',
#  'forty-eight',
#  'stretch',
#  'ninety-six',
#  'arduous',
#  'peril',
#  'working',
#  'sum',
#  'may',
#  'keep',
#  'fortnight',
#  'sleep',
#  'repeating',
#  'decimal',
#  'answer',
#  'kill',
#  'quiet',
#  'easy-going',
#  'afraid',
#  'bullied',
#  'very',
#  'gentle',
#  'brotherly',
#  'weakling',
#  'quite',
#  "a's",
#  'power',
#  'poor',
#  'undersized',
#  'frail',
#  'plaintive',
#  'face',
#  'constant',
#  'health',
#  'ruined',
#  'nervous',
#  'system',
#  'joyless',
#  'driven',
#  'drink',
#  'smoke',
#  'hand',
#  'shakes',
#  'digs',
#  'ditches',
#  'fact',
#  'saw',
#  'regatta',
#  'transpired',
#  'dead',
#  'fagged',
#  'coughing',
#  'badly',
#  'mind',
#  'fix',
#  'sofa',
#  'hot',
#  'tea',
#  'shouted',
#  'shown',
#  'says',
#  'we',
#  'until',
#  'to-morrow',
#  'night',
#  'beat',
#  'things',
#  'leaks',
#  'growl',
#  'dirty',
#  'shame',
#  'went',
#  'tell',
#  'sound',
#  'years',
#  'constantly',
#  'busy',
#  'eating',
#  'sleeping',
#  'owing',
#  'absence',
#  'sight',
#  'return',
#  'surprised',
#  'longer',
#  'accustomed',
#  'tasks',
#  'inquiry',
#  'line',
#  'done',
#  'n',
#  'm',
#  'o',
#  'employing',
#  'algebraica',
#  'jobs',
#  'foreigners',
#  'alpha',
#  'beta',
#  'gamma',
#  'delta',
#  'chanced',
#  'stumbled',
#  'front',
#  'cottage',
#  'hoeing',
#  'sun',
#  'aged',
#  'labouring',
#  'occasionally',
#  'help',
#  'why',
#  'knowed',
#  'since',
#  'brackets',
#  'fine',
#  'lad',
#  'give',
#  'kind-heartedness-like',
#  "many's",
#  "we've",
#  'together',
#  'nor',
#  'aught',
#  'labour',
#  'getting',
#  'stiff',
#  'nowadays',
#  'sir--just',
#  'scratch',
#  'grow',
#  'logarithm',
#  'raise',
#  'common',
#  'denominator',
#  'mr',
#  'euclid',
#  'use',
#  'still',
#  'propositions',
#  'garrulous',
#  'learned',
#  'former',
#  'acquaintances',
#  'told',
#  'river',
#  'running',
#  'refused',
#  'lying',
#  'helpless',
#  'shook',
#  'roughly',
#  "we're",
#  'looked',
#  'worn',
#  'pitiful',
#  'look',
#  "won't",
#  'stand',
#  "isn't",
#  'fit',
#  'to-night',
#  'smiled',
#  'feebly',
#  'perhaps',
#  'thoroughly',
#  'alarmed',
#  "he's",
#  'dying',
#  'flared',
#  "you've",
#  'reduce',
#  'lowest',
#  'terms',
#  'firmly',
#  "that'll",
#  'saved',
#  'made',
#  'medicine',
#  'nurse',
#  'accidentally',
#  'removed',
#  'changing',
#  'sign',
#  'fatal',
#  'blunder',
#  'sunk',
#  'next',
#  'shadows',
#  'deepened',
#  'room',
#  'clear',
#  'near',
#  'affected',
#  'bowed',
#  'aimlessly',
#  'offering',
#  'laboured',
#  'breathing',
#  'whispered',
#  "you'll",
#  'go',
#  'murmured',
#  "don't",
#  'rate."--the',
#  'rallied',
#  'moment',
#  'asked',
#  'downstairs',
#  'arms',
#  'expired',
#  'soul',
#  'sped',
#  'heavenward',
#  'its',
#  'flight',
#  'admiration',
#  'burst',
#  'passionate',
#  'flood',
#  'tears',
#  'sobbed',
#  'away',
#  'clothes',
#  'wear',
#  'feel',
#  'hardly',
#  'again."--the',
#  'funeral',
#  'unostentatious',
#  'differed',
#  'nothing',
#  'ordinary',
#  'except',
#  'out',
#  'deference',
#  'sporting',
#  'mathematicians',
#  'engaged',
#  'hearses',
#  'vehicles',
#  'started',
#  'bore',
#  'sable',
#  'parallelopiped',
#  'containing',
#  'remains',
#  'ill-fated',
#  'friend',
#  'box',
#  'empty',
#  'hearse',
#  'generously',
#  'consented',
#  'handicap',
#  'hundred',
#  'yards',
#  'arrived',
#  'distance',
#  'sarcophagus',
#  'lowered',
#  'grave',
#  'surrounded',
#  'figures',
#  'book',
#  'euclid.--it',
#  'noticed',
#  'changed',
#  'dug',
#  'languidly',
#  'finally',
#  'gave',
#  'settled',
#  'down',
#  'live',
#  'bets.--b',
#  'recovered',
#  'shock',
#  'grief',
#  'preyed',
#  'intellect',
#  'deranged',
#  'grew',
#  'moody',
#  'monosyllables',
#  'disease',
#  'aggravated',
#  'whose',
#  'spelling',
#  'regular',
#  'presented',
#  'difficulty',
#  'beginner',
#  'realizing',
#  'precarious',
#  'condition',
#  'voluntarily',
#  'submitted',
#  'incarcerated',
#  'asylum',
#  'where',
#  'abjured',
#  'devoted',
#  'writing',
#  'swiss',
#  'robinson',
#  'syllable']

# %% [markdown]
# ### 5. Rozšiřte předchozí program tak, že hodnotou bude n-tice o dvou prvcích – prvním bude počet výskytů daného slova v textu, druhým jeho relativní četnost v % (vzhledem k počtu všech slov v textu).

# %%
# TODO: Implement your solution.

# %% [markdown]
# ### 6.  Napište funkci, která spojí dohromady dva slovníky.
#
# **Ukázka:** `{"a": 1, "b": 2, "c": 3}, {"d": 7, "e": 8} => {"a": 1, "b": 2, "c": 3, "d": 7, "e": 8}`

# %%
a_to_c = {"a": 1, "b": 2, "c": 3, "d" : 8}
d_to_e = {"d": 7, "e": 8}

# %%
# TODO: Implement your solution.
dict3 = {**a_to_c , **d_to_e}

dict3
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 7, 'e': 8}

# %%
# TODO: Implement your solution.
a_to_c.update(d_to_e)
a_to_c
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 7, 'e': 8}

# %%
# TODO: Implement your solution.
def merge(lhs, rhs):
    
    
    for

# %% [markdown]
# ### 7. Napište funkci, která bude „obracet“ slovník. Bude brát slovník jako jediný argument a vrátí nový slovník, ve kterém budou hodnoty ze vstupního slovníku převedeny na klíče a klíče na hodnoty.
#
# **Ukázka:** `{1: 'A', 2: 'B'} => {'A': 1, 'B': 2}`

# %%
to_revert = {1: 'A', 2: 'B'}

# %%
# TODO: Implement your solution.


to_revert = { value : key for key, value in to_revert.items() }

to_revert
# Out:
# {'A': 1, 'B': 2}

# %%
# TODO: Implement your solution.

# %% [markdown]
# ### 8. Upravte předchozí program tak, aby bral v potaz skutečnost, že hodnoty nemusí být unikátní. Pro každou hodnotu tedy bude vytvářet seznam původních klíčů.
#
# **Ukázka:** `{1: 'A', 2: 'B', 3: 'B', 4: 'A', 5: 'C'} => {'A': [1,4], 'B': [2,3], 'C': [5]}`

# %%
to_revert_with_duplicates = {1: 'A', 2: 'B', 3: 'B', 4: 'A', 5: 'C'}

# %%
# TODO: Implement your solution.
d = {}
to_revert_with_duplicates = { d[value] = key if d.get(value) is None else d[value] += key for key, value in to_revert_with_duplicates.items() }


to_revert_with_duplicates
# Out:
#   File "<ipython-input-60-008eb90b4ba1>", line 3
#     to_revert_with_duplicates = { d[value] = key if d.get(value) is None else d[value] += key for key, value in to_revert_with_duplicates.items() }
#                                            ^
# SyntaxError: invalid syntax
